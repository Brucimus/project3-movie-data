# %%
#import pandas
import pandas as pd
#import csv module
import csv

#save file address with needed data as variables
movie_data_to_load = "tmdb_5000_movies.csv"
credits_data_to_load = "tmdb_5000_credits.csv"

# Initialize lists to store the cleaned data
movie_rows = []
credits_rows = []

# %%
# Create function to replace the problematic characters in the string item with a space
def replace_problematic_characters(item):
    item = item.replace('\r', '').replace('\n', '\\n')
    item = item.replace('"', '')
    return item

# Read the movie data file and store the cleaned data in the movie_rows list
with open(movie_data_to_load, 'r', encoding='utf-8') as movie_file:
    csv_reader = csv.reader(movie_file, quoting=csv.QUOTE_MINIMAL)
    movie_headers = next(csv_reader)
    for row in csv_reader:
        cleaned_row = [replace_problematic_characters(item) for item in row]
        movie_rows.append(cleaned_row)

# Read the credits data file and store the cleaned data in the credits_rows list
with open(credits_data_to_load, 'r', encoding='utf-8') as credits_file:
    csv_reader = csv.reader(credits_file, quoting=csv.QUOTE_MINIMAL)
    credits_headers = next(csv_reader)
    for row in csv_reader:
        cleaned_row = [replace_problematic_characters(item) for item in row]
        credits_rows.append(cleaned_row)

# %%
# Create Pandas DataFrames from the cleaned data
movie_data = pd.DataFrame(movie_rows, columns=movie_headers)
credits_data = pd.DataFrame(credits_rows, columns=credits_headers)

# %%
#count the total number of movies in movies file by counting the number of rows with id column as reference
movies_count = movie_data['id'].count()

#display count of movies
movies_count
# Out:
# 4803

# %%
#count the total number of movies in credits file by counting the number of rows with movie_id column as reference
credits_count = credits_data['movie_id'].count()

#display count of movies
credits_count
# Out:
# 4803

# %%
# Remove the "keywords", "overview" and "homepage" columns
movie_data.drop(["keywords", "overview", "homepage"], axis=1, inplace=True)

movie_data.head()
# Out:
#       budget                                             genres      id  \
# 0  237000000  [{id: 28, name: Action}, {id: 12, name: Advent...   19995
# 1  300000000  [{id: 12, name: Adventure}, {id: 14, name: Fan...     285
# 2  245000000  [{id: 28, name: Action}, {id: 12, name: Advent...  206647
# 3  250000000  [{id: 28, name: Action}, {id: 80, name: Crime}...   49026
# 4  260000000  [{id: 28, name: Action}, {id: 12, name: Advent...   49529
#
#   original_language                            original_title  popularity  \
# 0                en                                    Avatar  150.437577
# 1                en  Pirates of the Caribbean: At World's End  139.082615
# 2                en                                   Spectre  107.376788
# 3                en                     The Dark Knight Rises   112.31295
# 4                en                               John Carter   43.926995
#
#                                 production_companies  \
# 0  [{name: Ingenious Film Partners, id: 289}, {na...
# 1  [{name: Walt Disney Pictures, id: 2}, {name: J...
# 2  [{name: Columbia Pictures, id: 5}, {name: Danj...
# 3  [{name: Legendary Pictures, id: 923}, {name: W...
# 4              [{name: Walt Disney Pictures, id: 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{iso_3166_1: US, name: United States of Ameri...   2009-12-10  2787965087
# 1  [{iso_3166_1: US, name: United States of Ameri...   2007-05-19   961000000
# 2  [{iso_3166_1: GB, name: United Kingdom}, {iso_...   2015-10-26   880674609
# 3  [{iso_3166_1: US, name: United States of Ameri...   2012-07-16  1084939099
# 4  [{iso_3166_1: US, name: United States of Ameri...   2012-03-07   284139100
#
#   runtime                                   spoken_languages    status  \
# 0     162  [{iso_639_1: en, name: English}, {iso_639_1: e...  Released
# 1     169                   [{iso_639_1: en, name: English}]  Released
# 2     148  [{iso_639_1: fr, name: Fran\u00e7ais}, {iso_63...  Released
# 3     165                   [{iso_639_1: en, name: English}]  Released
# 4     132                   [{iso_639_1: en, name: English}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
# 2                                   Spectre          6.3       4466
# 3                     The Dark Knight Rises          7.6       9106
# 4                               John Carter          6.1       2124

# %%
#rearrange columns
movie_data = movie_data[['title', 'budget', 'genres', 'id', 'original_language', 'original_title', 'popularity', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'vote_average', 'vote_count']]

movie_data.head()
# Out:
#                                       title     budget  \
# 0                                    Avatar  237000000
# 1  Pirates of the Caribbean: At World's End  300000000
# 2                                   Spectre  245000000
# 3                     The Dark Knight Rises  250000000
# 4                               John Carter  260000000
#
#                                               genres      id  \
# 0  [{id: 28, name: Action}, {id: 12, name: Advent...   19995
# 1  [{id: 12, name: Adventure}, {id: 14, name: Fan...     285
# 2  [{id: 28, name: Action}, {id: 12, name: Advent...  206647
# 3  [{id: 28, name: Action}, {id: 80, name: Crime}...   49026
# 4  [{id: 28, name: Action}, {id: 12, name: Advent...   49529
#
#   original_language                            original_title  popularity  \
# 0                en                                    Avatar  150.437577
# 1                en  Pirates of the Caribbean: At World's End  139.082615
# 2                en                                   Spectre  107.376788
# 3                en                     The Dark Knight Rises   112.31295
# 4                en                               John Carter   43.926995
#
#                                 production_companies  \
# 0  [{name: Ingenious Film Partners, id: 289}, {na...
# 1  [{name: Walt Disney Pictures, id: 2}, {name: J...
# 2  [{name: Columbia Pictures, id: 5}, {name: Danj...
# 3  [{name: Legendary Pictures, id: 923}, {name: W...
# 4              [{name: Walt Disney Pictures, id: 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{iso_3166_1: US, name: United States of Ameri...   2009-12-10  2787965087
# 1  [{iso_3166_1: US, name: United States of Ameri...   2007-05-19   961000000
# 2  [{iso_3166_1: GB, name: United Kingdom}, {iso_...   2015-10-26   880674609
# 3  [{iso_3166_1: US, name: United States of Ameri...   2012-07-16  1084939099
# 4  [{iso_3166_1: US, name: United States of Ameri...   2012-03-07   284139100
#
#   runtime                                   spoken_languages    status  \
# 0     162  [{iso_639_1: en, name: English}, {iso_639_1: e...  Released
# 1     169                   [{iso_639_1: en, name: English}]  Released
# 2     148  [{iso_639_1: fr, name: Fran\u00e7ais}, {iso_63...  Released
# 3     165                   [{iso_639_1: en, name: English}]  Released
# 4     132                   [{iso_639_1: en, name: English}]  Released
#
#                                           tagline vote_average vote_count
# 0                     Enter the World of Pandora.          7.2      11800
# 1  At the end of the world, the adventure begins.          6.9       4500
# 2                           A Plan No One Escapes          6.3       4466
# 3                                 The Legend Ends          7.6       9106
# 4            Lost in our world, found in another.          6.1       2124

# %%
# Remove rows where the specified columns contain non-numeric values
cols = ['budget', 'popularity', 'revenue', 'runtime', 'vote_average', 'vote_count']
movie_data = movie_data[pd.concat([pd.to_numeric(movie_data[col], errors='coerce').notna() for col in cols], axis=1).all(axis=1)]

#Remove rows where the specific columns contain non-date values
movie_data['release_date'] = pd.to_datetime(movie_data['release_date'], errors='coerce')
movie_data = movie_data.dropna(subset=['release_date'])

# %%
#change column name cast to actors in credits table
credits_data = credits_data.rename(columns={'cast': 'actors'})
#rearrange headers
credits_data = credits_data[['title', 'movie_id', 'actors', 'crew']]

#display count of students across all schools
credits_data.head()
# Out:
#                                       title movie_id  \
# 0                                    Avatar    19995
# 1  Pirates of the Caribbean: At World's End      285
# 2                                   Spectre   206647
# 3                     The Dark Knight Rises    49026
# 4                               John Carter    49529
#
#                                               actors  \
# 0  [{cast_id: 242, character: Jake Sully, credit_...
# 1  [{cast_id: 4, character: Captain Jack Sparrow,...
# 2  [{cast_id: 1, character: James Bond, credit_id...
# 3  [{cast_id: 2, character: Bruce Wayne / Batman,...
# 4  [{cast_id: 5, character: John Carter, credit_i...
#
#                                                 crew
# 0  [{credit_id: 52fe48009251416c750aca23, departm...
# 1  [{credit_id: 52fe4232c3a36847f800b579, departm...
# 2  [{credit_id: 54805967c3a36829b5002c41, departm...
# 3  [{credit_id: 52fe4781c3a36847f81398c3, departm...
# 4  [{credit_id: 52fe479ac3a36847f813eaa3, departm...

# %%
movie_data_final = movie_data.merge(credits_data, on='title')

movie_data_final
# Out:
#                                          title     budget  \
# 0                                       Avatar  237000000
# 1     Pirates of the Caribbean: At World's End  300000000
# 2                                      Spectre  245000000
# 3                        The Dark Knight Rises  250000000
# 4                                  John Carter  260000000
# ...                                        ...        ...
# 4801                               El Mariachi     220000
# 4802                                 Newlyweds       9000
# 4803                 Signed, Sealed, Delivered          0
# 4804                          Shanghai Calling          0
# 4805                         My Date with Drew          0
#
#                                                  genres      id  \
# 0     [{id: 28, name: Action}, {id: 12, name: Advent...   19995
# 1     [{id: 12, name: Adventure}, {id: 14, name: Fan...     285
# 2     [{id: 28, name: Action}, {id: 12, name: Advent...  206647
# 3     [{id: 28, name: Action}, {id: 80, name: Crime}...   49026
# 4     [{id: 28, name: Action}, {id: 12, name: Advent...   49529
# ...                                                 ...     ...
# 4801  [{id: 28, name: Action}, {id: 80, name: Crime}...    9367
# 4802  [{id: 35, name: Comedy}, {id: 10749, name: Rom...   72766
# 4803  [{id: 35, name: Comedy}, {id: 18, name: Drama}...  231617
# 4804                                                 []  126186
# 4805                      [{id: 99, name: Documentary}]   25975
#
#      original_language                            original_title  popularity  \
# 0                   en                                    Avatar  150.437577
# 1                   en  Pirates of the Caribbean: At World's End  139.082615
# 2                   en                                   Spectre  107.376788
# 3                   en                     The Dark Knight Rises   112.31295
# 4                   en                               John Carter   43.926995
# ...                ...                                       ...         ...
# 4801                es                               El Mariachi   14.269792
# 4802                en                                 Newlyweds    0.642552
# 4803                en                 Signed, Sealed, Delivered    1.444476
# 4804                en                          Shanghai Calling    0.857008
# 4805                en                         My Date with Drew    1.929883
#
#                                    production_companies  \
# 0     [{name: Ingenious Film Partners, id: 289}, {na...
# 1     [{name: Walt Disney Pictures, id: 2}, {name: J...
# 2     [{name: Columbia Pictures, id: 5}, {name: Danj...
# 3     [{name: Legendary Pictures, id: 923}, {name: W...
# 4                 [{name: Walt Disney Pictures, id: 2}]
# ...                                                 ...
# 4801                 [{name: Columbia Pictures, id: 5}]
# 4802                                                 []
# 4803  [{name: Front Street Pictures, id: 3958}, {nam...
# 4804                                                 []
# 4805  [{name: rusty bear entertainment, id: 87986}, ...
#
#                                    production_countries release_date  \
# 0     [{iso_3166_1: US, name: United States of Ameri...   2009-12-10
# 1     [{iso_3166_1: US, name: United States of Ameri...   2007-05-19
# 2     [{iso_3166_1: GB, name: United Kingdom}, {iso_...   2015-10-26
# 3     [{iso_3166_1: US, name: United States of Ameri...   2012-07-16
# 4     [{iso_3166_1: US, name: United States of Ameri...   2012-03-07
# ...                                                 ...          ...
# 4801  [{iso_3166_1: MX, name: Mexico}, {iso_3166_1: ...   1992-09-04
# 4802                                                 []   2011-12-26
# 4803  [{iso_3166_1: US, name: United States of Ameri...   2013-10-13
# 4804  [{iso_3166_1: US, name: United States of Ameri...   2012-05-03
# 4805  [{iso_3166_1: US, name: United States of Ameri...   2005-08-05
#
#          revenue runtime                                   spoken_languages  \
# 0     2787965087     162  [{iso_639_1: en, name: English}, {iso_639_1: e...
# 1      961000000     169                   [{iso_639_1: en, name: English}]
# 2      880674609     148  [{iso_639_1: fr, name: Fran\u00e7ais}, {iso_63...
# 3     1084939099     165                   [{iso_639_1: en, name: English}]
# 4      284139100     132                   [{iso_639_1: en, name: English}]
# ...          ...     ...                                                ...
# 4801     2040920      81              [{iso_639_1: es, name: Espa\u00f1ol}]
# 4802           0      85                                                 []
# 4803           0     120                   [{iso_639_1: en, name: English}]
# 4804           0      98                   [{iso_639_1: en, name: English}]
# 4805           0      90                   [{iso_639_1: en, name: English}]
#
#         status                                            tagline  \
# 0     Released                        Enter the World of Pandora.
# 1     Released     At the end of the world, the adventure begins.
# 2     Released                              A Plan No One Escapes
# 3     Released                                    The Legend Ends
# 4     Released               Lost in our world, found in another.
# ...        ...                                                ...
# 4801  Released  He didn't come looking for trouble, but troubl...
# 4802  Released  A newlywed couple's honeymoon is upended by th...
# 4803  Released
# 4804  Released                           A New Yorker in Shanghai
# 4805  Released
#
#      vote_average vote_count movie_id  \
# 0             7.2      11800    19995
# 1             6.9       4500      285
# 2             6.3       4466   206647
# 3             7.6       9106    49026
# 4             6.1       2124    49529
# ...           ...        ...      ...
# 4801          6.6        238     9367
# 4802          5.9          5    72766
# 4803          7.0          6   231617
# 4804          5.7          7   126186
# 4805          6.3         16    25975
#
#                                                  actors  \
# 0     [{cast_id: 242, character: Jake Sully, credit_...
# 1     [{cast_id: 4, character: Captain Jack Sparrow,...
# 2     [{cast_id: 1, character: James Bond, credit_id...
# 3     [{cast_id: 2, character: Bruce Wayne / Batman,...
# 4     [{cast_id: 5, character: John Carter, credit_i...
# ...                                                 ...
# 4801  [{cast_id: 1, character: El Mariachi, credit_i...
# 4802  [{cast_id: 1, character: Buzzy, credit_id: 52f...
# 4803  [{cast_id: 8, character: Oliver O\u2019Toole, ...
# 4804  [{cast_id: 3, character: Sam, credit_id: 52fe4...
# 4805  [{cast_id: 3, character: Herself, credit_id: 5...
#
#                                                    crew
# 0     [{credit_id: 52fe48009251416c750aca23, departm...
# 1     [{credit_id: 52fe4232c3a36847f800b579, departm...
# 2     [{credit_id: 54805967c3a36829b5002c41, departm...
# 3     [{credit_id: 52fe4781c3a36847f81398c3, departm...
# 4     [{credit_id: 52fe479ac3a36847f813eaa3, departm...
# ...                                                 ...
# 4801  [{credit_id: 52fe44eec3a36847f80b280b, departm...
# 4802  [{credit_id: 52fe487dc3a368484e0fb013, departm...
# 4803  [{credit_id: 52fe4df3c3a36847f8275ecf, departm...
# 4804  [{credit_id: 52fe4ad9c3a368484e16a36b, departm...
# 4805  [{credit_id: 58ce021b9251415a390165d9, departm...
#
# [4806 rows x 20 columns]

# %%
# Export movie_data to a CSV file
movie_data_final.to_csv("movie_data.csv", index=False)
